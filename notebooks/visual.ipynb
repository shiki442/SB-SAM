# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
P1 = [1.99997, 2.00249, 2.00350, 2.00091, 2.00067]
P2 = [2.18414, 2.24362, 2.37191, 2.34398, 2.64112]
P3 = [1.77715, 1.73691, 2.11056, 1.92051, 2.00262]
P4 = [1.89069, 1.87819, 2.31866, 2.08622, 2.30426]
n = np.arange(3,8)
print(n)
plt.plot(n, P1, label='Stress with true f  and true x', linestyle="--")
plt.plot(n, P2, label='Stress with true f  and pred x')
plt.plot(n, P3, label='Stress with score s  and true x')
plt.plot(n, P4, label='Stress with score s  and pred x')
plt.ylim(0.0, 3.0)
plt.legend()
# Out:
# [3 4 5 6 7]
